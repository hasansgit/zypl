# %% [markdown]
# # Асосҳои Pandas

# %% [markdown]
# Дар ин ноутбук мо бо имкониятҳои асосии `pandas` шинос хоҳем шуд. Ин модул ҳаҷми бузург дорад, бинобар ин мо танҳо як миқдори маҳдуди онро меомӯзем ва машқ мекунем. [Маълумоти муфассал](https://pandas.pydata.org/docs/reference/index.html)

# %% [markdown]
# Тартибдиҳанда: Ҳакимов Раҳматҷон. Email: rahmatjon@gmail.com. Telegram: https://t.me/rahmatjon_hakimov

# %% [markdown]
# # Шиносоии аввлин

# %% [markdown]
# Истифодаи pandas-ро эълон мекунем:

# %%
import pandas as pd  # pd лақаб барои pandas

# %% [markdown]
# Маълумотро аз csv-файл мехонем:

# %%
data = pd.read_csv('purchases.csv', sep = ';')

# %% [markdown]
# Дар тағйирёбандаи data чӣ ҳаст?

# %%
data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 14  2024-05-09                                      Огурцы т/т   0.228
# 15  2024-05-09                                          БАНАНЫ   1.036
# 16  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 18  2024-07-15                             3.45 с Хлеб (43425)   1.000
# 19  2024-07-15                             Тухм 30 шт (566084)   1.000
# 20  2024-07-15                      0.15 с Пакет маль. (11421)   1.000
# 21  2024-05-29                            Арахис в глазуре 626   0.492
# 22         NaN                                Дрожжи Юва 15гр.   1.000
# 23         NaN                   Масло Мол/р Сливоч 150гр марг   1.000
#
#      price      market
# 0     7.47  Амид 19мкр
# 1     5.50  Амид 19мкр
# 2     4.95  Амид 19мкр
# 3    34.90  Амид 19мкр
# 4     3.80  Амид 19мкр
# 5    16.30  Амид 19мкр
# 6     0.20  Амид 19мкр
# 7    11.50        Доро
# 8     9.45        Доро
# 9    19.60        Доро
# 10  115.80        Доро
# 11   57.00        Доро
# 12   94.00        Доро
# 13  120.60        Доро
# 14    4.90        Доро
# 15   23.90        Доро
# 16    8.00        Доро
# 17    3.10       Оазис
# 18    3.45       Оазис
# 19   22.00       Оазис
# 20    0.15       Оазис
# 21   20.80         NaN
# 22    1.60         NaN
# 23    2.55         NaN

# %% [markdown]
# Аз ин чоп тасаввуроти умумӣ оиди мӯҳтавои файли purchases.csv гирифтан мумкин аст.

# %% [markdown]
# Аён аст, ки дар ҷадвал ҳам маълумоти ададӣ ва ҳам маълумоти сифатӣ/сатрӣ нигоҳ дошта шуда метавонад.

# %% [markdown]
# Намуди тағйирёбандаи data:

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Шарҳи маълумоти дар сутунҳо сабтшуда:
#  - *date* - санаи харид
#  - *item* - номгӯи маҳсулот
#  - *volume* - миқдори харидашуда
#  - *price* - нарх
#  - *market* - мағоза

# %% [markdown]
# Андозаи ҷадвалро мебинем:

# %%
data.shape
# Out:
# (24, 5)

# %% [markdown]
# Барои чоп кардани ҳамагӣ якчанд сатри ҷадвал аз методи `head` истифода мебарем:

# %%
data.head() # .head(x) x - по умолчанию => 5, x = min(x, .shape[0])
# Out:
#          date                                      item  volume  price  \
# 0  2024-06-27  Плит шок Нестле 82гр Горький шоколад 70%   1.000   7.47
# 1  2024-06-27                           Огурцы Орзу 104   0.398   5.50
# 2  2024-06-27                             Огурцы Т 3960   0.394   4.95
# 3  2024-06-27                             Гелос 1 (492)   0.306  34.90
# 4  2024-06-27                             Помидор 103 м   0.962   3.80
#
#        market
# 0  Амид 19мкр
# 1  Амид 19мкр
# 2  Амид 19мкр
# 3  Амид 19мкр
# 4  Амид 19мкр

# %%
data.head(3)
# Out:
#          date                                      item  volume  price  \
# 0  2024-06-27  Плит шок Нестле 82гр Горький шоколад 70%   1.000   7.47
# 1  2024-06-27                           Огурцы Орзу 104   0.398   5.50
# 2  2024-06-27                             Огурцы Т 3960   0.394   4.95
#
#        market
# 0  Амид 19мкр
# 1  Амид 19мкр
# 2  Амид 19мкр

# %% [markdown]
# Тағйирёбандаи data ва натиҷаи data.head() як намуд доранд:

# %%
type(data.head())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Барои гирифтани маълумот оиди мӯҳтавои ҷадвал аз методи `info` истифода мебаранд:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    21 non-null     object
#  1   item    23 non-null     object
#  2   volume  24 non-null     float64
#  3   price   24 non-null     float64
#  4   market  21 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 1.1+ KB

# %% [markdown]
# Омори (статистикаи) содда барои майдонҳои ададии ҷадвали data (методи `describe`):

# %%
data.describe()
# Out:
#           volume       price
# count  24.000000   24.000000
# mean    0.870583   24.646667
# std     0.790454   35.680288
# min     0.208000    0.150000
# 25%     0.348500    3.712500
# 50%     0.981000    8.725000
# 75%     1.000000   22.475000
# max     4.000000  120.600000

# %%
y = data.head(6)
y.describe()
# Out:
#          volume      price
# count  6.000000   6.000000
# mean   0.621333  12.153333
# std    0.304175  12.020585
# min    0.306000   3.800000
# 25%    0.395000   5.087500
# 50%    0.533000   6.485000
# 75%    0.888500  14.092500
# max    1.000000  34.900000

# %%
y
# Out:
#          date                                      item  volume  price  \
# 0  2024-06-27  Плит шок Нестле 82гр Горький шоколад 70%   1.000   7.47
# 1  2024-06-27                           Огурцы Орзу 104   0.398   5.50
# 2  2024-06-27                             Огурцы Т 3960   0.394   4.95
# 3  2024-06-27                             Гелос 1 (492)   0.306  34.90
# 4  2024-06-27                             Помидор 103 м   0.962   3.80
# 5         NaN                            Болгарский 407   0.668  16.30
#
#        market
# 0  Амид 19мкр
# 1  Амид 19мкр
# 2  Амид 19мкр
# 3  Амид 19мкр
# 4  Амид 19мкр
# 5  Амид 19мкр

# %% [markdown]
# Сутуни алоҳидаи DataFrame тавассути номаш дастрас мешавад:

# %%
data['price']
# Out:
# 0       7.47
# 1       5.50
# 2       4.95
# 3      34.90
# 4       3.80
# 5      16.30
# 6       0.20
# 7      11.50
# 8       9.45
# 9      19.60
# 10    115.80
# 11     57.00
# 12     94.00
# 13    120.60
# 14      4.90
# 15     23.90
# 16      8.00
# 17      3.10
# 18      3.45
# 19     22.00
# 20      0.15
# 21     20.80
# 22      1.60
# 23      2.55
# Name: price, dtype: float64

# %%
type(data['price'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Бо сутунҳо амалҳоро элемент-ба-элемент иҷро кардан мумкин аст:

# %%
data['price'] * data['volume']
# Out:
# 0      7.4700
# 1      2.1890
# 2      1.9503
# 3     10.6794
# 4      3.6556
# 5     10.8884
# 6      0.2000
# 7     11.5000
# 8      9.4500
# 9      6.8600
# 10    24.0864
# 11    15.9600
# 12    32.3360
# 13    27.4968
# 14     1.1172
# 15    24.7604
# 16    16.0000
# 17    12.4000
# 18     3.4500
# 19    22.0000
# 20     0.1500
# 21    10.2336
# 22     1.6000
# 23     2.5500
# dtype: float64

# %% [markdown]
# Ба ҷадвали data сутуни нав илова кардан мумкин аст:

# %%
data['summa'] = data['price'] * data['volume']
data.head(10)
# Out:
#          date                                      item  volume  price  \
# 0  2024-06-27  Плит шок Нестле 82гр Горький шоколад 70%   1.000   7.47
# 1  2024-06-27                           Огурцы Орзу 104   0.398   5.50
# 2  2024-06-27                             Огурцы Т 3960   0.394   4.95
# 3  2024-06-27                             Гелос 1 (492)   0.306  34.90
# 4  2024-06-27                             Помидор 103 м   0.962   3.80
# 5         NaN                            Болгарский 407   0.668  16.30
# 6  2024-05-17                                       NaN   1.000   0.20
# 7  2024-05-09                          Пряники "Ягодка"   1.000  11.50
# 8  2024-05-09      Напиток "Fanta" апельсин-яблоко 1,25   1.000   9.45
# 9  2024-05-09                              Помидоры т/т   0.350  19.60
#
#        market    summa
# 0  Амид 19мкр   7.4700
# 1  Амид 19мкр   2.1890
# 2  Амид 19мкр   1.9503
# 3  Амид 19мкр  10.6794
# 4  Амид 19мкр   3.6556
# 5  Амид 19мкр  10.8884
# 6  Амид 19мкр   0.2000
# 7        Доро  11.5000
# 8        Доро   9.4500
# 9        Доро   6.8600

# %% [markdown]
# Ҳамаи тағйиротҳои ҷадвал дар хотираи фаврӣ (дар тағйирёбандаҳо Python) нигоҳ дошта мешаванд; ба маълумоти файл таъсир намерасонанд:

# %%
demo_data = pd.read_csv('purchases.csv', sep = ';')
demo_data.columns
# Out:
# Index(['date', 'item', 'volume', 'price', 'market'], dtype='object')

# %%
data.to_csv('purchases_new.csv', sep=';', index=False, encoding='utf-8')

# %% [markdown]
# Сутуни ҷадвалро бо воситаи `del` ё методи `pop` хориҷ (delete) кардан мумкин аст:

# %%
del data['market']  # Тарзи дигар: data.pop('market')

# %%
data.head()
# Out:
#          date                                      item  volume  price  \
# 0  2024-06-27  Плит шок Нестле 82гр Горький шоколад 70%   1.000   7.47
# 1  2024-06-27                           Огурцы Орзу 104   0.398   5.50
# 2  2024-06-27                             Огурцы Т 3960   0.394   4.95
# 3  2024-06-27                             Гелос 1 (492)   0.306  34.90
# 4  2024-06-27                             Помидор 103 м   0.962   3.80
#
#      summa
# 0   7.4700
# 1   2.1890
# 2   1.9503
# 3  10.6794
# 4   3.6556

# %% [markdown]
# Сутунҳои ҷадвали pandas ҳамчун массиви дарозиаш тағйирёбанда ҳастанд. Сутунҳо соҳиби бисёр методҳои барои аналитика/таҳлил муфид мебошанд:

# %%
data['item']
# Out:
# 0           Плит шок Нестле 82гр Горький шоколад 70%
# 1                                    Огурцы Орзу 104
# 2                                      Огурцы Т 3960
# 3                                      Гелос 1 (492)
# 4                                      Помидор 103 м
# 5                                     Болгарский 407
# 6                                                NaN
# 7                                   Пряники "Ягодка"
# 8               Напиток "Fanta" апельсин-яблоко 1,25
# 9                                       Помидоры т/т
# 10               Конфеты "Бабаевские" трюфел/крем РТ
# 11                           Конфеты "Тотти" Suvorov
# 12        Конфеты "Бабаевские" с фундуком и какао РТ
# 13    Конфеты "Вдохновение" Миндаль и Фундук Крем РТ
# 14                                        Огурцы т/т
# 15                                            БАНАНЫ
# 16                              Напиток "RC Cola" 1л
# 17            Мороженое "Ты+Я" Дусти Алишер (565828)
# 18                               3.45 с Хлеб (43425)
# 19                               Тухм 30 шт (566084)
# 20                        0.15 с Пакет маль. (11421)
# 21                              Арахис в глазуре 626
# 22                                  Дрожжи Юва 15гр.
# 23                     Масло Мол/р Сливоч 150гр марг
# Name: item, dtype: object

# %%
type(data['item'])
# Out:
# pandas.core.series.Series

# %%
help(pd.core.series.Series.value_counts)
# Out:
# Help on function value_counts in module pandas.core.base:
#
# value_counts(self, normalize: 'bool' = False, sort: 'bool' = True, ascending: 'bool' = False, bins=None, dropna: 'bool' = True) -> 'Series'
#     Return a Series containing counts of unique values.
#
#     The resulting object will be in descending order so that the
#     first element is the most frequently-occurring element.
#     Excludes NA values by default.
#
#     Parameters
#     ----------
#     normalize : bool, default False
#         If True then the object returned will contain the relative
#         frequencies of the unique values.
#     sort : bool, default True
#         Sort by frequencies when True. Preserve the order of the data when False.
#     ascending : bool, default False
#         Sort in ascending order.
#     bins : int, optional
#         Rather than count values, group them into half-open bins,
#         a convenience for ``pd.cut``, only works with numeric data.
#     dropna : bool, default True
#         Don't include counts of NaN.
#
#     Returns
#     -------
#     Series
#
#     See Also
#     --------
#     Series.count: Number of non-NA elements in a Series.
#     DataFrame.count: Number of non-NA elements in a DataFrame.
#     DataFrame.value_counts: Equivalent method on DataFrames.
#
#     Examples
#     --------
#     >>> index = pd.Index([3, 1, 2, 3, 4, np.nan])
#     >>> index.value_counts()
#     3.0    2
#     1.0    1
#     2.0    1
#     4.0    1
#     Name: count, dtype: int64
#
#     With `normalize` set to `True`, returns the relative frequency by
#     dividing all values by the sum of values.
#
#     >>> s = pd.Series([3, 1, 2, 3, 4, np.nan])
#     >>> s.value_counts(normalize=True)
#     3.0    0.4
#     1.0    0.2
#     2.0    0.2
#     4.0    0.2
#     Name: proportion, dtype: float64
#
#     **bins**
#
#     Bins can be useful for going from a continuous variable to a
#     categorical variable; instead of counting unique
#     apparitions of values, divide the index in the specified
#     number of half-open bins.
#
#     >>> s.value_counts(bins=3)
#     (0.996, 2.0]    2
#     (2.0, 3.0]      2
#     (3.0, 4.0]      1
#     Name: count, dtype: int64
#
#     **dropna**
#
#     With `dropna` set to `False` we can also see NaN index values.
#
#     >>> s.value_counts(dropna=False)
#     3.0    2
#     1.0    1
#     2.0    1
#     4.0    1
#     NaN    1
#     Name: count, dtype: int64

# %%
count_of_markets = demo_data['market'].value_counts()
count_of_markets
# Out:
# market
# Доро          10
# Амид 19мкр     7
# Оазис          4
# Name: count, dtype: int64

# %%
type(count_of_markets)
# Out:
# pandas.core.series.Series

# %%
count_of_volumes = demo_data['volume'].value_counts()
count_of_volumes
# Out:
# volume
# 1.000    9
# 0.228    2
# 0.398    1
# 0.394    1
# 0.306    1
# 0.962    1
# 0.668    1
# 0.350    1
# 0.208    1
# 0.280    1
# 0.344    1
# 1.036    1
# 2.000    1
# 4.000    1
# 0.492    1
# Name: count, dtype: int64

# %%
date_group = demo_data['date'].value_counts()

# %%
type(date_group)
# Out:
# pandas.core.series.Series

# %%
date_group
# Out:
# date
# 2024-05-09    10
# 2024-06-27     5
# 2024-07-15     4
# 2024-05-17     1
# 2024-05-29     1
# Name: count, dtype: int64

# %%
int(count_of_markets['Оазис'])
# Out:
# 4

# %%
date_group['2024-05-09']
# Out:
# np.int64(10)

# %%
data['price'].sort_values(ascending=False)[:5]
# Out:
# 11    120.6
# 8     115.8
# 10     94.0
# 9      57.0
# 3      34.9
# Name: price, dtype: float64

# %%
data['price'].sort_values(ascending=False).head()
# Out:
# 11    120.6
# 8     115.8
# 10     94.0
# 9      57.0
# 3      34.9
# Name: price, dtype: float64

# %%
data['price'].sort_values(ascending=False).tail()
# Out:
# 12    4.90
# 4     3.80
# 16    3.45
# 15    3.10
# 18    0.15
# Name: price, dtype: float64

# %%
data.sort_values(ascending=False,by = 'summa')
# Out:
#           date                                            item  volume  \
# 10  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 11  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 13  2024-05-09                                          БАНАНЫ   1.036
# 8   2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 17  2024-07-15                             Тухм 30 шт (566084)   1.000
# 14  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 9   2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 15  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 5   2024-05-09                                Пряники "Ягодка"   1.000
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 6   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 0   2024-06-27        Плит шок Победа 82гр Горький шоколад 70%   1.000
# 7   2024-05-09                                    Помидоры т/т   0.350
# 4   2024-06-27                                   Помидор 103 м   0.962
# 16  2024-07-15                             3.45 с Хлеб (43425)   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 12  2024-05-09                                      Огурцы т/т   0.228
# 18  2024-07-15                      0.15 с Пакет маль. (11421)   1.000
#
#      price    summa
# 10   94.00  32.3360
# 11  120.60  27.4968
# 13   23.90  24.7604
# 8   115.80  24.0864
# 17   22.00  22.0000
# 14    8.00  16.0000
# 9    57.00  15.9600
# 15    3.10  12.4000
# 5    11.50  11.5000
# 3    34.90  10.6794
# 6     9.45   9.4500
# 0     7.47   7.4700
# 7    19.60   6.8600
# 4     3.80   3.6556
# 16    3.45   3.4500
# 1     5.50   2.1890
# 2     4.95   1.9503
# 12    4.90   1.1172
# 18    0.15   0.1500

# %%
data['price'] > 6
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15    False
# 16    False
# 17     True
# 18    False
# Name: price, dtype: bool

# %%
data[data['summa'] > 6].sort_values(ascending=False,by = 'summa')
# Out:
#           date                                            item  volume  \
# 10  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 11  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 13  2024-05-09                                          БАНАНЫ   1.036
# 8   2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 17  2024-07-15                             Тухм 30 шт (566084)   1.000
# 14  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 9   2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 15  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 5   2024-05-09                                Пряники "Ягодка"   1.000
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 6   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 0   2024-06-27        Плит шок Победа 82гр Горький шоколад 70%   1.000
# 7   2024-05-09                                    Помидоры т/т   0.350
#
#      price    summa
# 10   94.00  32.3360
# 11  120.60  27.4968
# 13   23.90  24.7604
# 8   115.80  24.0864
# 17   22.00  22.0000
# 14    8.00  16.0000
# 9    57.00  15.9600
# 15    3.10  12.4000
# 5    11.50  11.5000
# 3    34.90  10.6794
# 6     9.45   9.4500
# 0     7.47   7.4700
# 7    19.60   6.8600

# %%
demo_data[demo_data['market'].isin(['Доро', 'Оазис'])]
# Out:
#           date                                            item  volume  \
# 5   2024-05-09                                Пряники "Ягодка"   1.000
# 6   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 7   2024-05-09                                    Помидоры т/т   0.350
# 8   2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 9   2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 10  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 11  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 12  2024-05-09                                      Огурцы т/т   0.228
# 13  2024-05-09                                          БАНАНЫ   1.036
# 14  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 15  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 16  2024-07-15                             3.45 с Хлеб (43425)   1.000
# 17  2024-07-15                             Тухм 30 шт (566084)   1.000
# 18  2024-07-15                      0.15 с Пакет маль. (11421)   1.000
#
#      price market
# 5    11.50   Доро
# 6     9.45   Доро
# 7    19.60   Доро
# 8   115.80   Доро
# 9    57.00   Доро
# 10   94.00   Доро
# 11  120.60   Доро
# 12    4.90   Доро
# 13   23.90   Доро
# 14    8.00   Доро
# 15    3.10  Оазис
# 16    3.45  Оазис
# 17   22.00  Оазис
# 18    0.15  Оазис

# %%
data['sum'] = data['summa'].apply(lambda sum : round(sum, 2))

# %%
data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 14  2024-05-09                                      Огурцы т/т   0.228
# 15  2024-05-09                                          БАНАНЫ   1.036
# 16  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 18  2024-07-15                             3.45 с Хлеб (43425)   1.000
# 19  2024-07-15                             Тухм 30 шт (566084)   1.000
# 20  2024-07-15                      0.15 с Пакет маль. (11421)   1.000
# 21  2024-05-29                            Арахис в глазуре 626   0.492
# 22         NaN                                Дрожжи Юва 15гр.   1.000
# 23         NaN                   Масло Мол/р Сливоч 150гр марг   1.000
#
#      price    summa  new_sum    sum
# 0     7.47   7.4700     7.47   7.47
# 1     5.50   2.1890     2.19   2.19
# 2     4.95   1.9503     1.95   1.95
# 3    34.90  10.6794    10.68  10.68
# 4     3.80   3.6556     3.66   3.66
# 5    16.30  10.8884    10.89  10.89
# 6     0.20   0.2000     0.20   0.20
# 7    11.50  11.5000    11.50  11.50
# 8     9.45   9.4500     9.45   9.45
# 9    19.60   6.8600     6.86   6.86
# 10  115.80  24.0864    24.09  24.09
# 11   57.00  15.9600    15.96  15.96
# 12   94.00  32.3360    32.34  32.34
# 13  120.60  27.4968    27.50  27.50
# 14    4.90   1.1172     1.12   1.12
# 15   23.90  24.7604    24.76  24.76
# 16    8.00  16.0000    16.00  16.00
# 17    3.10  12.4000    12.40  12.40
# 18    3.45   3.4500     3.45   3.45
# 19   22.00  22.0000    22.00  22.00
# 20    0.15   0.1500     0.15   0.15
# 21   20.80  10.2336    10.23  10.23
# 22    1.60   1.6000     1.60   1.60
# 23    2.55   2.5500     2.55   2.55

# %%
new_data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%    1.00
# 1   2024-06-27                                 Огурцы Орзу 104    0.40
# 2   2024-06-27                                   Огурцы Т 3960    0.39
# 3   2024-06-27                                   Гелос 1 (492)    0.31
# 4   2024-06-27                                   Помидор 103 м    0.96
# 5          NaN                                  Болгарский 407    0.67
# 6   2024-05-17                                             NaN    1.00
# 7   2024-05-09                                Пряники "Ягодка"    1.00
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25    1.00
# 9   2024-05-09                                    Помидоры т/т    0.35
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ    0.21
# 11  2024-05-09                         Конфеты "Тотти" Suvorov    0.28
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ    0.34
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ    0.23
# 14  2024-05-09                                      Огурцы т/т    0.23
# 15  2024-05-09                                          БАНАНЫ    1.04
# 16  2024-05-09                            Напиток "RC Cola" 1л    2.00
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)    4.00
# 18  2024-07-15                             3.45 с Хлеб (43425)    1.00
# 19  2024-07-15                             Тухм 30 шт (566084)    1.00
# 20  2024-07-15                      0.15 с Пакет маль. (11421)    1.00
# 21  2024-05-29                            Арахис в глазуре 626    0.49
# 22         NaN                                Дрожжи Юва 15гр.    1.00
# 23         NaN                   Масло Мол/р Сливоч 150гр марг    1.00
#
#      price  summa
# 0     7.47   7.47
# 1     5.50   2.19
# 2     4.95   1.95
# 3    34.90  10.68
# 4     3.80   3.66
# 5    16.30  10.89
# 6     0.20   0.20
# 7    11.50  11.50
# 8     9.45   9.45
# 9    19.60   6.86
# 10  115.80  24.09
# 11   57.00  15.96
# 12   94.00  32.34
# 13  120.60  27.50
# 14    4.90   1.12
# 15   23.90  24.76
# 16    8.00  16.00
# 17    3.10  12.40
# 18    3.45   3.45
# 19   22.00  22.00
# 20    0.15   0.15
# 21   20.80  10.23
# 22    1.60   1.60
# 23    2.55   2.55

# %%
del data['new_sum']

# %%
data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 14  2024-05-09                                      Огурцы т/т   0.228
# 15  2024-05-09                                          БАНАНЫ   1.036
# 16  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 18  2024-07-15                             3.45 с Хлеб (43425)   1.000
# 19  2024-07-15                             Тухм 30 шт (566084)   1.000
# 20  2024-07-15                      0.15 с Пакет маль. (11421)   1.000
# 21  2024-05-29                            Арахис в глазуре 626   0.492
# 22         NaN                                Дрожжи Юва 15гр.   1.000
# 23         NaN                   Масло Мол/р Сливоч 150гр марг   1.000
#
#      price    summa    sum
# 0     7.47   7.4700   7.47
# 1     5.50   2.1890   2.19
# 2     4.95   1.9503   1.95
# 3    34.90  10.6794  10.68
# 4     3.80   3.6556   3.66
# 5    16.30  10.8884  10.89
# 6     0.20   0.2000   0.20
# 7    11.50  11.5000  11.50
# 8     9.45   9.4500   9.45
# 9    19.60   6.8600   6.86
# 10  115.80  24.0864  24.09
# 11   57.00  15.9600  15.96
# 12   94.00  32.3360  32.34
# 13  120.60  27.4968  27.50
# 14    4.90   1.1172   1.12
# 15   23.90  24.7604  24.76
# 16    8.00  16.0000  16.00
# 17    3.10  12.4000  12.40
# 18    3.45   3.4500   3.45
# 19   22.00  22.0000  22.00
# 20    0.15   0.1500   0.15
# 21   20.80  10.2336  10.23
# 22    1.60   1.6000   1.60
# 23    2.55   2.5500   2.55

# %%
data['summa'] = data['sum']

# %%
del data['sum']

# %%
data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 14  2024-05-09                                      Огурцы т/т   0.228
# 15  2024-05-09                                          БАНАНЫ   1.036
# 16  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 18  2024-07-15                             3.45 с Хлеб (43425)   1.000
# 19  2024-07-15                             Тухм 30 шт (566084)   1.000
# 20  2024-07-15                      0.15 с Пакет маль. (11421)   1.000
# 21  2024-05-29                            Арахис в глазуре 626   0.492
# 22         NaN                                Дрожжи Юва 15гр.   1.000
# 23         NaN                   Масло Мол/р Сливоч 150гр марг   1.000
#
#      price  summa
# 0     7.47   7.47
# 1     5.50   2.19
# 2     4.95   1.95
# 3    34.90  10.68
# 4     3.80   3.66
# 5    16.30  10.89
# 6     0.20   0.20
# 7    11.50  11.50
# 8     9.45   9.45
# 9    19.60   6.86
# 10  115.80  24.09
# 11   57.00  15.96
# 12   94.00  32.34
# 13  120.60  27.50
# 14    4.90   1.12
# 15   23.90  24.76
# 16    8.00  16.00
# 17    3.10  12.40
# 18    3.45   3.45
# 19   22.00  22.00
# 20    0.15   0.15
# 21   20.80  10.23
# 22    1.60   1.60
# 23    2.55   2.55

# %%
data.to_excel('purchases_new_excel.xlsx', index=False)

# %%
xlsx_data = pd.read_excel('purchases_new_excel.xlsx')

# %%
xlsx_data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 14  2024-05-09                                      Огурцы т/т   0.228
# 15  2024-05-09                                          БАНАНЫ   1.036
# 16  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 18  2024-07-15                             3.45 с Хлеб (43425)   1.000
# 19  2024-07-15                             Тухм 30 шт (566084)   1.000
# 20  2024-07-15                      0.15 с Пакет маль. (11421)   1.000
# 21  2024-05-29                            Арахис в глазуре 626   0.492
# 22         NaN                                Дрожжи Юва 15гр.   1.000
# 23         NaN                   Масло Мол/р Сливоч 150гр марг   1.000
#
#      price  summa
# 0     7.47   7.47
# 1     5.50   2.19
# 2     4.95   1.95
# 3    34.90  10.68
# 4     3.80   3.66
# 5    16.30  10.89
# 6     0.20   0.20
# 7    11.50  11.50
# 8     9.45   9.45
# 9    19.60   6.86
# 10  115.80  24.09
# 11   57.00  15.96
# 12   94.00  32.34
# 13  120.60  27.50
# 14    4.90   1.12
# 15   23.90  24.76
# 16    8.00  16.00
# 17    3.10  12.40
# 18    3.45   3.45
# 19   22.00  22.00
# 20    0.15   0.15
# 21   20.80  10.23
# 22    1.60   1.60
# 23    2.55   2.55

# %%
xlsx_data.drop(22)
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 14  2024-05-09                                      Огурцы т/т   0.228
# 15  2024-05-09                                          БАНАНЫ   1.036
# 16  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 18  2024-07-15                             3.45 с Хлеб (43425)   1.000
# 19  2024-07-15                             Тухм 30 шт (566084)   1.000
# 20  2024-07-15                      0.15 с Пакет маль. (11421)   1.000
# 21  2024-05-29                            Арахис в глазуре 626   0.492
# 23         NaN                   Масло Мол/р Сливоч 150гр марг   1.000
#
#      price  summa
# 0     7.47   7.47
# 1     5.50   2.19
# 2     4.95   1.95
# 3    34.90  10.68
# 4     3.80   3.66
# 5    16.30  10.89
# 6     0.20   0.20
# 7    11.50  11.50
# 8     9.45   9.45
# 9    19.60   6.86
# 10  115.80  24.09
# 11   57.00  15.96
# 12   94.00  32.34
# 13  120.60  27.50
# 14    4.90   1.12
# 15   23.90  24.76
# 16    8.00  16.00
# 17    3.10  12.40
# 18    3.45   3.45
# 19   22.00  22.00
# 20    0.15   0.15
# 21   20.80  10.23
# 23    2.55   2.55

# %%
xlsx_data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 14  2024-05-09                                      Огурцы т/т   0.228
# 15  2024-05-09                                          БАНАНЫ   1.036
# 16  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 18  2024-07-15                             3.45 с Хлеб (43425)   1.000
# 19  2024-07-15                             Тухм 30 шт (566084)   1.000
# 20  2024-07-15                      0.15 с Пакет маль. (11421)   1.000
# 21  2024-05-29                            Арахис в глазуре 626   0.492
# 22         NaN                                Дрожжи Юва 15гр.   1.000
# 23         NaN                   Масло Мол/р Сливоч 150гр марг   1.000
#
#      price  summa
# 0     7.47   7.47
# 1     5.50   2.19
# 2     4.95   1.95
# 3    34.90  10.68
# 4     3.80   3.66
# 5    16.30  10.89
# 6     0.20   0.20
# 7    11.50  11.50
# 8     9.45   9.45
# 9    19.60   6.86
# 10  115.80  24.09
# 11   57.00  15.96
# 12   94.00  32.34
# 13  120.60  27.50
# 14    4.90   1.12
# 15   23.90  24.76
# 16    8.00  16.00
# 17    3.10  12.40
# 18    3.45   3.45
# 19   22.00  22.00
# 20    0.15   0.15
# 21   20.80  10.23
# 22    1.60   1.60
# 23    2.55   2.55

# %%
xlsx_data.dropna()
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 14  2024-05-09                                      Огурцы т/т   0.228
# 15  2024-05-09                                          БАНАНЫ   1.036
# 16  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 18  2024-07-15                             3.45 с Хлеб (43425)   1.000
# 19  2024-07-15                             Тухм 30 шт (566084)   1.000
# 20  2024-07-15                      0.15 с Пакет маль. (11421)   1.000
# 21  2024-05-29                            Арахис в глазуре 626   0.492
#
#      price  summa
# 0     7.47   7.47
# 1     5.50   2.19
# 2     4.95   1.95
# 3    34.90  10.68
# 4     3.80   3.66
# 7    11.50  11.50
# 8     9.45   9.45
# 9    19.60   6.86
# 10  115.80  24.09
# 11   57.00  15.96
# 12   94.00  32.34
# 13  120.60  27.50
# 14    4.90   1.12
# 15   23.90  24.76
# 16    8.00  16.00
# 17    3.10  12.40
# 18    3.45   3.45
# 19   22.00  22.00
# 20    0.15   0.15
# 21   20.80  10.23

# %%
import datetime
xlsx_data['data'] = xlsx_data['date'].fillna(datetime.datetime.now().date())

# %%
xlsx_data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 14  2024-05-09                                      Огурцы т/т   0.228
# 15  2024-05-09                                          БАНАНЫ   1.036
# 16  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 18  2024-07-15                             3.45 с Хлеб (43425)   1.000
# 19  2024-07-15                             Тухм 30 шт (566084)   1.000
# 20  2024-07-15                      0.15 с Пакет маль. (11421)   1.000
# 21  2024-05-29                            Арахис в глазуре 626   0.492
# 22         NaN                                Дрожжи Юва 15гр.   1.000
# 23         NaN                   Масло Мол/р Сливоч 150гр марг   1.000
#
#      price  summa        data
# 0     7.47   7.47  2024-06-27
# 1     5.50   2.19  2024-06-27
# 2     4.95   1.95  2024-06-27
# 3    34.90  10.68  2024-06-27
# 4     3.80   3.66  2024-06-27
# 5    16.30  10.89  2024-07-29
# 6     0.20   0.20  2024-05-17
# 7    11.50  11.50  2024-05-09
# 8     9.45   9.45  2024-05-09
# 9    19.60   6.86  2024-05-09
# 10  115.80  24.09  2024-05-09
# 11   57.00  15.96  2024-05-09
# 12   94.00  32.34  2024-05-09
# 13  120.60  27.50  2024-05-09
# 14    4.90   1.12  2024-05-09
# 15   23.90  24.76  2024-05-09
# 16    8.00  16.00  2024-05-09
# 17    3.10  12.40  2024-07-15
# 18    3.45   3.45  2024-07-15
# 19   22.00  22.00  2024-07-15
# 20    0.15   0.15  2024-07-15
# 21   20.80  10.23  2024-05-29
# 22    1.60   1.60  2024-07-29
# 23    2.55   2.55  2024-07-29
